# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV

from sklearn.metrics import(

        accuracy_score,
        balanced_accuracy_score,
        f1_score,
        precision_score,
        recall_score,
        roc_auc_score,
        classification_report,
        confusion_matrix,
        ConfusionMatrixDisplay,
        roc_curve
)

# %% [markdown]
# # Preprocessing

# %%
df = pd.read_csv('customer_churn_feature.csv')
df.head(5)
# Out:
#    customer_id identity_segment  age  income  group_size  \
# 0      1000001           Couple   43   59373           1
# 1      1000002    Office Worker   36   87255           2
# 2      1000003           Couple   28  102362           3
# 3      1000004           Family   55  178855           7
# 4      1000005          Student   24   20379           3
#
#                 location preferred_price_tier preferred_rest_type  \
# 0             Whitefield            Mid-range         Fine Dining
# 1                    HSR               Budget                Cafe
# 2  Koramangala 5th Block            Mid-range                Cafe
# 3            Indiranagar            Mid-range       Casual Dining
# 4      Bannerghatta Road               Budget       Beverage Shop
#
#    total_spend  avg_order_value  ...  unique_restaurants  unique_cuisines  \
# 0    2052.3801       684.126678  ...                   3                3
# 1    8202.4990       630.961535  ...                  13               13
# 2   14056.7010       669.366669  ...                  21               17
# 3   10220.6600       567.814441  ...                  18               18
# 4    1250.0300       312.507505  ...                   4                3
#
#    unique_rest_types  restaurant_loyalty  cuisine_loyalty  \
# 0                  3            0.333333         0.333333
# 1                  3            0.076923         0.076923
# 2                  5            0.047619         0.190476
# 3                  3            0.055556         0.055556
# 4                  3            0.250000         0.500000
#
#    avg_actual_group_size  std_group_size  avg_price_deviation  \
# 0                    1.0             0.0           223.186676
# 1                    2.0             0.0           297.756919
# 2                    3.0             0.0           350.020945
# 3                    7.0             0.0           167.776671
# 4                    3.0             0.0           138.842499
#
#    rest_type_match_rate  churned
# 0              0.333333        0
# 1              0.846154        1
# 2              0.809524        1
# 3              0.833333        1
# 4              0.500000        1
#
# [5 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9258 entries, 0 to 9257
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            9258 non-null   int64
#  1   identity_segment       9258 non-null   object
#  2   age                    9258 non-null   int64
#  3   income                 9258 non-null   int64
#  4   group_size             9258 non-null   int64
#  5   location               9258 non-null   object
#  6   preferred_price_tier   9258 non-null   object
#  7   preferred_rest_type    9258 non-null   object
#  8   total_spend            9258 non-null   float64
#  9   avg_order_value        9258 non-null   float64
#  10  median_order_value     9258 non-null   float64
#  11  std_order_value        8486 non-null   float64
#  12  max_order_value        9258 non-null   float64
#  13  recency_days           9258 non-null   float64
#  14  mean_order_gap         8486 non-null   float64
#  15  std_order_gap          7611 non-null   float64
#  16  min_order_gap          8486 non-null   float64
#  17  max_order_gap          8486 non-null   float64
#  18  orders_first_30d       9258 non-null   int64
#  19  orders_middle_30d      9258 non-null   int64
#  20  orders_last_30d        9258 non-null   int64
#  21  orders_last_7d         9258 non-null   int64
#  22  orders_last_14d        9258 non-null   int64
#  23  spend_first_30d        8357 non-null   float64
#  24  spend_middle_30d       7063 non-null   float64
#  25  spend_last_30d         5962 non-null   float64
#  26  unique_restaurants     9258 non-null   int64
#  27  unique_cuisines        9258 non-null   int64
#  28  unique_rest_types      9258 non-null   int64
#  29  restaurant_loyalty     9258 non-null   float64
#  30  cuisine_loyalty        9258 non-null   float64
#  31  avg_actual_group_size  9258 non-null   float64
#  32  std_group_size         8486 non-null   float64
#  33  avg_price_deviation    9258 non-null   float64
#  34  rest_type_match_rate   9258 non-null   float64
#  35  churned                9258 non-null   int64
# dtypes: float64(19), int64(13), object(4)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#         customer_id          age         income   group_size    total_spend  \
# count  9.258000e+03  9258.000000    9258.000000  9258.000000    9258.000000
# mean   1.005001e+06    30.436487   70618.655001     1.916721    7747.708253
# std    2.886728e+03     8.781438   42353.173259     1.268135   11655.660706
# min    1.000001e+06    18.000000   10012.000000     1.000000      76.380000
# 25%    1.002502e+06    23.000000   32989.500000     1.000000    1767.829975
# 50%    1.005004e+06    29.000000   66183.500000     1.000000    4046.559800
# 75%    1.007496e+06    37.000000   96706.750000     2.000000    8911.889250
# max    1.010000e+06    55.000000  179979.000000    10.000000  162073.050000
#
#        avg_order_value  median_order_value  std_order_value  max_order_value  \
# count      9258.000000         9258.000000      8486.000000      9258.000000
# mean        655.725630          617.167704       299.370276      1149.942404
# std         384.962658          386.214981       228.283370       751.470191
# min          76.379997           76.379997         0.367688        76.380000
# 25%         405.716247          373.727497       161.914528       654.985000
# 50%         548.385005          510.695007       231.739087       935.015000
# 75%         758.964668          704.085022       352.573521      1379.440000
# max        3513.290039         3513.290039      2189.789441      7030.450000
#
#        recency_days  ...  unique_restaurants  unique_cuisines  \
# count   9258.000000  ...         9258.000000      9258.000000
# mean      27.025059  ...           11.144956         9.187730
# std       27.509787  ...           13.324964         9.905221
# min        0.000000  ...            1.000000         1.000000
# 25%        3.900002  ...            3.000000         3.000000
# 50%       14.599998  ...            7.000000         6.000000
# 75%       48.299999  ...           13.750000        12.000000
# max       89.800000  ...          103.000000        77.000000
#
#        unique_rest_types  restaurant_loyalty  cuisine_loyalty  \
# count        9258.000000         9258.000000      9258.000000
# mean            2.757183            0.266146         0.331938
# std             1.965242            0.272020         0.266530
# min             1.000000            0.009709         0.032258
# 25%             1.000000            0.083333         0.142857
# 50%             2.000000            0.166667         0.250000
# 75%             4.000000            0.333333         0.500000
# max            17.000000            1.000000         1.000000
#
#        avg_actual_group_size  std_group_size  avg_price_deviation  \
# count            9258.000000          8486.0          9258.000000
# mean                1.916721             0.0           286.139945
# std                 1.268135             0.0           219.442985
# min                 1.000000             0.0             0.279999
# 25%                 1.000000             0.0           148.710000
# 50%                 1.000000             0.0           220.481068
# 75%                 2.000000             0.0           349.380438
# max                10.000000             0.0          2729.629883
#
#        rest_type_match_rate      churned
# count           9258.000000  9258.000000
# mean               0.746170     0.413588
# std                0.266421     0.492503
# min                0.000000     0.000000
# 25%                0.640000     0.000000
# 50%                0.808365     0.000000
# 75%                1.000000     1.000000
# max                1.000000     1.000000
#
# [8 rows x 32 columns]

# %%
df.isna().sum()
# Out:
# customer_id                 0
# identity_segment            0
# age                         0
# income                      0
# group_size                  0
# location                    0
# preferred_price_tier        0
# preferred_rest_type         0
# total_spend                 0
# avg_order_value             0
# median_order_value          0
# std_order_value           772
# max_order_value             0
# recency_days                0
# mean_order_gap            772
# std_order_gap            1647
# min_order_gap             772
# max_order_gap             772
# orders_first_30d            0
# orders_middle_30d           0
# orders_last_30d             0
# orders_last_7d              0
# orders_last_14d             0
# spend_first_30d           901
# spend_middle_30d         2195
# spend_last_30d           3296
# unique_restaurants          0
# unique_cuisines             0
# unique_rest_types           0
# restaurant_loyalty          0
# cuisine_loyalty             0
# avg_actual_group_size       0
# std_group_size            772
# avg_price_deviation         0
# rest_type_match_rate        0
# churned                     0
# dtype: int64

# %%
print(df['churned'].value_counts())
print(df['churned'].value_counts(normalize=True))
# Out:
# churned
# 0    5429
# 1    3829
# Name: count, dtype: int64
# churned
# 0    0.586412
# 1    0.413588
# Name: proportion, dtype: float64

# %%
df[df.isna().any(axis=1)].head()
# Out:
#     customer_id identity_segment  age  income  group_size  \
# 3       1000004           Family   55  178855           7
# 4       1000005          Student   24   20379           3
# 6       1000007           Couple   24   83088           3
# 10      1000012    Food Explorer   29   80265           1
# 13      1000017           Family   27   64183           6
#
#                  location preferred_price_tier preferred_rest_type  \
# 3             Indiranagar            Mid-range       Casual Dining
# 4       Bannerghatta Road               Budget       Beverage Shop
# 6   Koramangala 1st Block            Mid-range        Microbrewery
# 10                Ejipura               Budget         Quick Bites
# 13            Frazer Town            Mid-range         Fine Dining
#
#     total_spend  avg_order_value  ...  unique_restaurants  unique_cuisines  \
# 3      10220.66       567.814441  ...                  18               18
# 4       1250.03       312.507505  ...                   4                3
# 6      25022.68      1471.922342  ...                  12                5
# 10      1386.72       462.239990  ...                   3                3
# 13      4860.38       972.075995  ...                   2                2
#
#     unique_rest_types  restaurant_loyalty  cuisine_loyalty  \
# 3                   3            0.055556         0.055556
# 4                   3            0.250000         0.500000
# 6                   2            0.117647         0.529412
# 10                  1            0.333333         0.333333
# 13                  1            0.800000         0.800000
#
#     avg_actual_group_size  std_group_size  avg_price_deviation  \
# 3                     7.0             0.0           167.776671
# 4                     3.0             0.0           138.842499
# 6                     3.0             0.0           610.503518
# 10                    1.0             0.0           274.239990
# 13                    6.0             0.0           583.507990
#
#     rest_type_match_rate  churned
# 3               0.833333        1
# 4               0.500000        1
# 6               0.823529        1
# 10              1.000000        0
# 13              1.000000        1
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Investigating all the columns with missing values

# %% [markdown]
# 1. first looking at columns with same number of missing values

# %%
df.loc[df['std_order_value'].isna(), ["customer_id", "total_spend", "avg_order_value", "std_order_value"]].head(20)
# Out:
#       customer_id  total_spend  avg_order_value  std_order_value
# 8486      1004634      2011.54      2011.540039              NaN
# 8487      1004276      1151.09      1151.089966              NaN
# 8488      1009135       203.46       203.460007              NaN
# 8489      1002703       578.52       578.520020              NaN
# 8490      1007619       670.37       670.369995              NaN
# 8491      1001300       473.51       473.510010              NaN
# 8492      1000649       523.17       523.169983              NaN
# 8493      1002744       326.80       326.799988              NaN
# 8494      1006695       192.51       192.509995              NaN
# 8495      1009402      1023.02      1023.020020              NaN
# 8496      1002135       776.19       776.190002              NaN
# 8497      1001774      1528.05      1528.050049              NaN
# 8498      1001398       269.47       269.470001              NaN
# 8499      1008373       708.82       708.820007              NaN
# 8500      1009152       500.58       500.579987              NaN
# 8501      1006263      1004.88      1004.880005              NaN
# 8502      1000436       265.85       265.850006              NaN
# 8503      1000133       914.67       914.669983              NaN
# 8504      1004356       490.79       490.790009              NaN
# 8505      1000389       182.73       182.729996              NaN

# %%
df.loc[df['mean_order_gap'].isna(), ["customer_id", "total_spend", "avg_order_value", "std_order_value"]].head(5)
# Out:
#       customer_id  total_spend  avg_order_value  std_order_value
# 8486      1004634      2011.54      2011.540039              NaN
# 8487      1004276      1151.09      1151.089966              NaN
# 8488      1009135       203.46       203.460007              NaN
# 8489      1002703       578.52       578.520020              NaN
# 8490      1007619       670.37       670.369995              NaN

# %%
df.loc[df['min_order_gap'].isna(), ["customer_id", "total_spend", "avg_order_value", "std_order_value"]].head(5)
# Out:
#       customer_id  total_spend  avg_order_value  std_order_value
# 8486      1004634      2011.54      2011.540039              NaN
# 8487      1004276      1151.09      1151.089966              NaN
# 8488      1009135       203.46       203.460007              NaN
# 8489      1002703       578.52       578.520020              NaN
# 8490      1007619       670.37       670.369995              NaN

# %%
df.loc[df['max_order_gap'].isna(), ["customer_id", "total_spend", "avg_order_value", "std_order_value"]].head(5)
# Out:
#       customer_id  total_spend  avg_order_value  std_order_value
# 8486      1004634      2011.54      2011.540039              NaN
# 8487      1004276      1151.09      1151.089966              NaN
# 8488      1009135       203.46       203.460007              NaN
# 8489      1002703       578.52       578.520020              NaN
# 8490      1007619       670.37       670.369995              NaN

# %%
df.loc[df['std_order_gap'].isna(), ["customer_id", "total_spend", "avg_order_value", "std_order_value"]].head(5)
# Out:
#     customer_id  total_spend  avg_order_value  std_order_value
# 23      1000027    653.16003       326.580002        75.391743
# 30      1000035   1041.15000       520.575005       390.669429
# 66      1000076    974.52000       487.259995        87.921655
# 71      1000081   1290.47000       645.234985        56.052368
# 74      1000084    723.17004       361.585007        67.281206

# %% [markdown]
# reason for null in std_order_gap
#
# * 1 order → no gap → NaN
# * 2 orders → one gap → standard deviation can't really be calculated → NaN
# * 3+ orders → multiple gaps → standard deviation can be calculated

# %% [markdown]
# 2. Rest of the columns with missing values

# %%
cols = [
        "spend_first_30d",
        "spend_middle_30d",
        "spend_last_30d"
]

df[cols] = df[cols].fillna(0)

# as std_group_size won't contribute much to the model also customer_id for training the model
df.drop(columns = ['std_group_size', 'customer_id'], inplace= True )

# %% [markdown]
# 30-day spending NaNs
#
# spend_first_30d, spend_middle_30d, and spend_last_30d are NaN when a customer placed no orders during that particular 30-day period.
# Since no orders means no spending, these should be treated as 0, not as a missing/unknown value.
#
# std_group_size
#
# Measures how much the customer's order group size varies across orders.
# It is not especially useful for our churn problem because there is no strong business reason or churn mechanism connecting group-size variability to churn.
# Also, it becomes NaN for customers with insufficient orders to calculate standard deviation.
# Therefore, we can drop std_group_size and keep the more interpretable avg_actual_group_size.

# %% [markdown]
# The NaNs represent genuine lack of information, not random missing data.
# XGBoost can handle missing numerical values natively, so we don't need to replace them with artificial values except for spend columns
# This also avoids unnecessary imputation and potential train/test leakage.

# %% [markdown]
# # Training the model

# %%
#creating the split

X = df.drop(columns='churned')
y = df['churned']

X_train, X_test, y_train, y_test = train_test_split(

    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# %%
# encoding the categorical columns

categorical_cols = [
        "identity_segment",
        "location",
        "preferred_price_tier",
        "preferred_rest_type" 
]

X_train = pd.get_dummies(X_train,
                         columns=categorical_cols,
                         dtype=int
                        )

X_test = pd.get_dummies(X_test,
                        columns=categorical_cols,
                        dtype=int
                       )

#Making X_test have the same columns as X_train. If a column exists in training but not in test, put 0
X_train, X_test = X_train.align(
    X_test,
    join="left",
    axis=1,
    fill_value=0
)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (6480, 153)
# (2778, 153)

# %% [markdown]
# ### Building Baseline Model

# %%
# Creating basic xgboost model

model = XGBClassifier(objective="binary:logistic", random_state = 42)

model.fit(X_train, y_train)
test_accuracy = model.score(X_test,y_test)
train_accuracy = model.score(X_train, y_train)

y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:,1]

print(f'Model accuracy:{test_accuracy}')
print(f'training accuracy:{train_accuracy}')
print(f'AUC_ROC_score:{roc_auc_score(y_test, y_prob)}')
# Out:
# Model accuracy:0.8696904247660188
# training accuracy:0.996141975308642
# AUC_ROC_score:0.9217223079721818

# %%
#confusion matrix

cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm,
                    display_labels=['Did not churn', 'Churned']).plot()
plt.show()

# %% [markdown]
# #### Baseline Model
#
# - The baseline XGBoost model achieved **86.97% test accuracy**, but its **99.61% training accuracy** indicates significant overfitting.
# - From the confusion matrix, the model has **243 false negatives**, resulting in a recall of approximately **78.9%**.
# - This means the baseline model misses around **21% of actual churners**, so improving recall is important for identifying more customers at risk of churn.

# %% [markdown]
# ### Tuning Hyperparameter

# %% [markdown]
# - **RandomizedSearchCV:** Randomly explores a wide range of hyperparameter combinations to efficiently identify a promising region of parameters.

# %%
param_dist = {
    'n_estimators' : [20, 30, 50, 80, 100, 150, 200, 250],
    'max_depth' : [2,3,4,5,8,16],
    'learning_rate' :[0.01, 0.05, 0.1, 0.2, 0.3],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'scale_pos_weight': [1, 2, 3], # helps with class imbalance 
    "min_child_weight": [1, 3, 5, 10],
    "gamma": [0, 0.1, 0.3, 0.5]
}

search = RandomizedSearchCV(
    estimator=XGBClassifier(objective='binary:logistic', eval_metric='aucpr', random_state=42),
    param_distributions=param_dist,
    n_iter=50,
    scoring='average_precision',
    cv=5,
    verbose=1,
    random_state=42
)

search.fit(X_train, y_train)
print("Best parameters found:")
print(search.best_params_)

print("\nBest cross-validation score (average precision):")
print(search.best_score_)

best_model = search.best_estimator_

results_df = pd.DataFrame(search.cv_results_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:
# {'subsample': 0.6, 'scale_pos_weight': 2, 'n_estimators': 80, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 0.6}
#
# Best cross-validation score (average precision):
# 0.9295828505687075

# %%
results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.495670      0.056283         0.058646        0.002490
# 1        2.593578      0.064892         0.066817        0.004842
# 2        0.912173      0.031240         0.058187        0.000975
# 3        2.123541      0.077184         0.065830        0.003228
# 4        1.599986      0.064172         0.062258        0.002542
# 5        1.146951      0.075342         0.063774        0.004448
# 6        0.494839      0.006790         0.058732        0.004307
# 7        0.413858      0.010614         0.064431        0.015412
# 8        0.997583      0.018038         0.060569        0.001542
# 9        0.316473      0.007479         0.059695        0.001513
# 10       0.929582      0.036990         0.060102        0.003343
# 11       0.565881      0.002591         0.058611        0.001747
# 12       0.288469      0.005130         0.064116        0.015228
# 13       0.473063      0.013998         0.058575        0.001482
# 14       0.372507      0.028080         0.064840        0.007614
# 15       1.179068      0.042874         0.060323        0.001897
# 16       1.418446      0.040659         0.063975        0.004628
# 17       2.349441      0.085542         0.067731        0.003895
# 18       0.673474      0.038611         0.059308        0.002333
# 19       3.465321      0.167555         0.066271        0.001862
# 20       1.059614      0.046734         0.062982        0.003677
# 21       5.150616      0.148404         0.065640        0.000841
# 22       1.139418      0.047626         0.061778        0.002450
# 23       0.797912      0.015204         0.057867        0.000402
# 24       2.213733      0.014580         0.069113        0.004071
# 25       0.279339      0.014110         0.069928        0.016707
# 26       3.666468      0.239737         0.063865        0.001392
# 27       0.787646      0.004913         0.058438        0.000490
# 28       3.298049      0.243768         0.061169        0.011891
# 29       0.268409      0.005592         0.060911        0.003375
# 30       1.411592      0.168478         0.060675        0.011024
# 31       0.272618      0.011707         0.060554        0.003962
# 32       0.522868      0.011924         0.064496        0.015490
# 33       1.347622      0.044964         0.065032        0.003927
# 34       3.779761      0.277202         0.067781        0.002598
# 35       1.242724      0.025542         0.070565        0.015792
# 36       0.562657      0.018410         0.059173        0.001507
# 37       0.847745      0.037221         0.062500        0.002787
# 38       0.366338      0.012757         0.058272        0.004666
# 39       0.935381      0.028735         0.060581        0.003146
# 40       0.832627      0.019150         0.058928        0.002941
# 41       0.491483      0.013037         0.060542        0.003935
# 42       1.123478      0.037747         0.059313        0.001770
# 43       0.785071      0.017855         0.057493        0.001735
# 44       0.673515      0.017158         0.057367        0.001234
# 45       0.263448      0.007812         0.059088        0.002963
# 46       1.524205      0.062569         0.065141        0.002240
# 47       1.519179      0.020129         0.062995        0.002393
# 48       0.330352      0.007513         0.061988        0.002981
# 49       1.421905      0.021649         0.061925        0.002113
#
#     param_subsample  param_scale_pos_weight  param_n_estimators  \
# 0               0.9                       2                  50
# 1               0.8                       1                 250
# 2               0.8                       2                  80
# 3               0.9                       2                 200
# 4               1.0                       3                 250
# 5               0.9                       1                 250
# 6               0.8                       2                  80
# 7               0.7                       1                  80
# 8               0.8                       3                  80
# 9               0.9                       1                  30
# 10              0.9                       1                  20
# 11              0.6                       3                  80
# 12              0.8                       2                  20
# 13              0.6                       2                  80
# 14              0.6                       2                  30
# 15              0.9                       2                 250
# 16              0.8                       1                 250
# 17              1.0                       1                 250
# 18              0.7                       2                 150
# 19              0.6                       2                 200
# 20              0.6                       2                  50
# 21              0.7                       3                 250
# 22              0.7                       2                 200
# 23              1.0                       2                 200
# 24              0.6                       1                 150
# 25              0.6                       3                  20
# 26              0.9                       3                 200
# 27              0.9                       2                 150
# 28              0.8                       1                 250
# 29              0.6                       1                  30
# 30              0.6                       3                 150
# 31              0.7                       2                  30
# 32              1.0                       2                  80
# 33              0.6                       3                 250
# 34              0.7                       2                 250
# 35              0.9                       3                  80
# 36              0.6                       2                  80
# 37              0.7                       3                 150
# 38              0.6                       3                  50
# 39              1.0                       2                 200
# 40              0.7                       2                 200
# 41              0.7                       2                  80
# 42              1.0                       1                 250
# 43              0.7                       2                 150
# 44              0.9                       3                 100
# 45              1.0                       2                  30
# 46              0.9                       1                 250
# 47              0.7                       2                 150
# 48              0.9                       3                  50
# 49              0.6                       3                 250
#
#     param_min_child_weight  param_max_depth  param_learning_rate  ...  \
# 0                        1                4                 0.10  ...
# 1                       10               16                 0.01  ...
# 2                       10                8                 0.01  ...
# 3                       10               16                 0.30  ...
# 4                        5                5                 0.05  ...
# 5                        5                3                 0.20  ...
# 6                        1                3                 0.10  ...
# 7                        3                2                 0.30  ...
# 8                        1                8                 0.10  ...
# 9                        3                4                 0.01  ...
# 10                       1               16                 0.01  ...
# 11                       5                4                 0.05  ...
# 12                       5                5                 0.05  ...
# 13                       5                3                 0.30  ...
# 14                       1                5                 0.10  ...
# 15                       5                3                 0.05  ...
# 16                       1                4                 0.10  ...
# 17                       3                8                 0.10  ...
# 18                       5                2                 0.30  ...
# 19                       1               16                 0.10  ...
# 20                       3               16                 0.01  ...
# 21                       1               16                 0.05  ...
# 22                       1                4                 0.30  ...
# 23                      10                2                 0.30  ...
# 24                       1               16                 0.30  ...
# 25                       5                4                 0.30  ...
# 26                       3               16                 0.05  ...
# 27                      10                3                 0.01  ...
# 28                       5               16                 0.01  ...
# 29                       1                2                 0.20  ...
# 30                      10                8                 0.10  ...
# 31                      10                2                 0.01  ...
# 32                       3                4                 0.30  ...
# 33                       3                4                 0.20  ...
# 34                       5               16                 0.01  ...
# 35                      10               16                 0.30  ...
# 36                       1                4                 0.05  ...
# 37                       5                4                 0.30  ...
# 38                       1                3                 0.30  ...
# 39                       1                3                 0.30  ...
# 40                       3                2                 0.30  ...
# 41                      10                3                 0.20  ...
# 42                       1                3                 0.20  ...
# 43                       1                3                 0.05  ...
# 44                       5                4                 0.01  ...
# 45                       5                2                 0.10  ...
# 46                      10                5                 0.20  ...
# 47                       5                8                 0.10  ...
# 48                      10                2                 0.20  ...
# 49                      10                4                 0.10  ...
#
#     param_colsample_bytree                                             params  \
# 0                      0.8  {'subsample': 0.9, 'scale_pos_weight': 2, 'n_e...
# 1                      0.8  {'subsample': 0.8, 'scale_pos_weight': 1, 'n_e...
# 2                      0.8  {'subsample': 0.8, 'scale_pos_weight': 2, 'n_e...
# 3                      1.0  {'subsample': 0.9, 'scale_pos_weight': 2, 'n_e...
# 4                      0.8  {'subsample': 1.0, 'scale_pos_weight': 3, 'n_e...
# 5                      0.7  {'subsample': 0.9, 'scale_pos_weight': 1, 'n_e...
# 6                      0.9  {'subsample': 0.8, 'scale_pos_weight': 2, 'n_e...
# 7                      0.6  {'subsample': 0.7, 'scale_pos_weight': 1, 'n_e...
# 8                      0.8  {'subsample': 0.8, 'scale_pos_weight': 3, 'n_e...
# 9                      0.7  {'subsample': 0.9, 'scale_pos_weight': 1, 'n_e...
# 10                     0.9  {'subsample': 0.9, 'scale_pos_weight': 1, 'n_e...
# 11                     0.9  {'subsample': 0.6, 'scale_pos_weight': 3, 'n_e...
# 12                     1.0  {'subsample': 0.8, 'scale_pos_weight': 2, 'n_e...
# 13                     0.6  {'subsample': 0.6, 'scale_pos_weight': 2, 'n_e...
# 14                     0.7  {'subsample': 0.6, 'scale_pos_weight': 2, 'n_e...
# 15                     1.0  {'subsample': 0.9, 'scale_pos_weight': 2, 'n_e...
# 16                     0.9  {'subsample': 0.8, 'scale_pos_weight': 1, 'n_e...
# 17                     1.0  {'subsample': 1.0, 'scale_pos_weight': 1, 'n_e...
# 18                     0.9  {'subsample': 0.7, 'scale_pos_weight': 2, 'n_e...
# 19                     1.0  {'subsample': 0.6, 'scale_pos_weight': 2, 'n_e...
# 20                     0.7  {'subsample': 0.6, 'scale_pos_weight': 2, 'n_e...
# 21                     1.0  {'subsample': 0.7, 'scale_pos_weight': 3, 'n_e...
# 22                     0.9  {'subsample': 0.7, 'scale_pos_weight': 2, 'n_e...
# 23                     0.9  {'subsample': 1.0, 'scale_pos_weight': 2, 'n_e...
# 24                     1.0  {'subsample': 0.6, 'scale_pos_weight': 1, 'n_e...
# 25                     0.8  {'subsample': 0.6, 'scale_pos_weight': 3, 'n_e...
# 26                     0.8  {'subsample': 0.9, 'scale_pos_weight': 3, 'n_e...
# 27                     0.8  {'subsample': 0.9, 'scale_pos_weight': 2, 'n_e...
# 28                     0.6  {'subsample': 0.8, 'scale_pos_weight': 1, 'n_e...
# 29                     0.8  {'subsample': 0.6, 'scale_pos_weight': 1, 'n_e...
# 30                     0.7  {'subsample': 0.6, 'scale_pos_weight': 3, 'n_e...
# 31                     0.8  {'subsample': 0.7, 'scale_pos_weight': 2, 'n_e...
# 32                     0.7  {'subsample': 1.0, 'scale_pos_weight': 2, 'n_e...
# 33                     0.7  {'subsample': 0.6, 'scale_pos_weight': 3, 'n_e...
# 34                     0.6  {'subsample': 0.7, 'scale_pos_weight': 2, 'n_e...
# 35                     1.0  {'subsample': 0.9, 'scale_pos_weight': 3, 'n_e...
# 36                     0.6  {'subsample': 0.6, 'scale_pos_weight': 2, 'n_e...
# 37                     0.6  {'subsample': 0.7, 'scale_pos_weight': 3, 'n_e...
# 38                     1.0  {'subsample': 0.6, 'scale_pos_weight': 3, 'n_e...
# 39                     0.8  {'subsample': 1.0, 'scale_pos_weight': 2, 'n_e...
# 40                     1.0  {'subsample': 0.7, 'scale_pos_weight': 2, 'n_e...
# 41                     1.0  {'subsample': 0.7, 'scale_pos_weight': 2, 'n_e...
# 42                     1.0  {'subsample': 1.0, 'scale_pos_weight': 1, 'n_e...
# 43                     0.9  {'subsample': 0.7, 'scale_pos_weight': 2, 'n_e...
# 44                     0.9  {'subsample': 0.9, 'scale_pos_weight': 3, 'n_e...
# 45                     0.9  {'subsample': 1.0, 'scale_pos_weight': 2, 'n_e...
# 46                     0.7  {'subsample': 0.9, 'scale_pos_weight': 1, 'n_e...
# 47                     1.0  {'subsample': 0.7, 'scale_pos_weight': 2, 'n_e...
# 48                     0.8  {'subsample': 0.9, 'scale_pos_weight': 3, 'n_e...
# 49                     1.0  {'subsample': 0.6, 'scale_pos_weight': 3, 'n_e...
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.932995           0.933855           0.924391           0.933479
# 1           0.932422           0.933495           0.924744           0.932319
# 2           0.930541           0.932886           0.924158           0.932051
# 3           0.916700           0.922544           0.914327           0.919969
# 4           0.927817           0.930142           0.922896           0.929955
# 5           0.923457           0.924697           0.918071           0.922571
# 6           0.933566           0.932490           0.924734           0.933880
# 7           0.925861           0.930472           0.921871           0.927593
# 8           0.926167           0.930186           0.918205           0.928261
# 9           0.929506           0.930551           0.920882           0.930929
# 10          0.923598           0.918678           0.918018           0.922635
# 11          0.931917           0.935003           0.924486           0.932775
# 12          0.932285           0.925604           0.922614           0.933323
# 13          0.926854           0.924014           0.920972           0.923506
# 14          0.933135           0.933344           0.925721           0.933020
# 15          0.930875           0.932789           0.924804           0.932059
# 16          0.927603           0.928191           0.920633           0.926372
# 17          0.922353           0.924663           0.917590           0.923653
# 18          0.924391           0.928385           0.919581           0.925921
# 19          0.923781           0.927192           0.916762           0.924551
# 20          0.929938           0.931443           0.922813           0.929429
# 21          0.926656           0.929120           0.919454           0.924770
# 22          0.922231           0.922047           0.916478           0.922310
# 23          0.925369           0.927517           0.919385           0.928809
# 24          0.920747           0.922005           0.915192           0.919808
# 25          0.929360           0.929092           0.922613           0.926455
# 26          0.925911           0.926919           0.918608           0.927655
# 27          0.931096           0.931951           0.925044           0.934559
# 28          0.930708           0.933491           0.922667           0.931145
# 29          0.931635           0.934403           0.924116           0.931545
# 30          0.922145           0.925531           0.921118           0.927015
# 31          0.905578           0.904621           0.899457           0.909440
# 32          0.923811           0.927193           0.920115           0.924141
# 33          0.920351           0.924537           0.915233           0.922714
# 34          0.929892           0.933284           0.922627           0.929809
# 35          0.921905           0.920184           0.912910           0.921401
# 36          0.931805           0.934149           0.926227           0.934291
# 37          0.919007           0.924000           0.914613           0.919177
# 38          0.925511           0.928372           0.917140           0.931113
# 39          0.919812           0.924386           0.918260           0.922936
# 40          0.924169           0.927402           0.922836           0.925170
# 41          0.929959           0.928082           0.923784           0.933445
# 42          0.924480           0.926488           0.920213           0.925173
# 43          0.933209           0.933647           0.925864           0.934116
# 44          0.933600           0.930551           0.923261           0.932733
# 45          0.918917           0.922351           0.915842           0.929607
# 46          0.921183           0.924545           0.916568           0.924531
# 47          0.923299           0.924703           0.919113           0.925750
# 48          0.930607           0.931506           0.924656           0.932660
# 49          0.925394           0.928548           0.919072           0.925536
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.920291         0.929002        0.005598                4
# 1            0.918642         0.928325        0.005763                8
# 2            0.918555         0.927638        0.005478               13
# 3            0.908124         0.916333        0.004967               49
# 4            0.917401         0.925642        0.004879               20
# 5            0.911312         0.920021        0.004895               40
# 6            0.919626         0.928859        0.005706                5
# 7            0.919929         0.925145        0.003816               21
# 8            0.914699         0.923504        0.005999               25
# 9            0.919033         0.926180        0.005135               19
# 10           0.912443         0.919075        0.003959               43
# 11           0.921079         0.929052        0.005327                3
# 12           0.918958         0.926557        0.005528               17
# 13           0.915768         0.922223        0.003729               31
# 14           0.918934         0.928831        0.005728                6
# 15           0.919657         0.928037        0.005049               11
# 16           0.917296         0.924019        0.004300               23
# 17           0.913597         0.920371        0.004165               37
# 18           0.918412         0.923338        0.003785               26
# 19           0.909034         0.920264        0.006590               38
# 20           0.917400         0.926205        0.005307               18
# 21           0.913327         0.922665        0.005648               30
# 22           0.909164         0.918446        0.005143               45
# 23           0.914324         0.923081        0.005442               28
# 24           0.905393         0.916629        0.006071               48
# 25           0.916263         0.924757        0.004891               22
# 26           0.911321         0.922083        0.006277               33
# 27           0.917788         0.928088        0.006020               10
# 28           0.917173         0.927037        0.006139               14
# 29           0.921336         0.928607        0.004989                7
# 30           0.915045         0.922171        0.004163               32
# 31           0.897884         0.903396        0.004212               50
# 32           0.913233         0.921699        0.004791               35
# 33           0.912528         0.919073        0.004524               44
# 34           0.917784         0.926679        0.005644               15
# 35           0.907033         0.916687        0.005816               47
# 36           0.921442         0.929583        0.005010                1
# 37           0.911633         0.917686        0.004241               46
# 38           0.916856         0.923798        0.005829               24
# 39           0.914905         0.920060        0.003372               39
# 40           0.914632         0.922842        0.004367               29
# 41           0.917809         0.926616        0.005395               16
# 42           0.914013         0.922073        0.004546               34
# 43           0.920319         0.929431        0.005473                2
# 44           0.920327         0.928094        0.005321                9
# 45           0.910856         0.919515        0.006304               41
# 46           0.910055         0.919376        0.005501               42
# 47           0.914711         0.921515        0.004083               36
# 48           0.920247         0.927935        0.004734               12
# 49           0.916952         0.923100        0.004357               27
#
# [50 rows x 21 columns]

# %% [markdown]
# - **GridSearchCV:** Using it to xxhaustively tests selected parameter combinations around the promising region found via RandomizedSearchCV to firther refine the model.

# %%
from sklearn.model_selection import GridSearchCV

param_dist = {
    'n_estimators' : [75,80,85],
    'max_depth' : [3,4,5],
    'learning_rate' :[0.04, 0.05, 0.06],
    'subsample': [0.4,0.5,0.6],
    'colsample_bytree': [0.4,0.5,0.6],
    "gamma": [0,0.1,0.2]
}

search = GridSearchCV(
    estimator=XGBClassifier(objective='binary:logistic', eval_metric='aucpr', random_state=42),
    param_grid=param_dist,
    scoring='average_precision',
    cv=5,
    verbose=1
)

search.fit(X_train, y_train)
print("Best parameters found:")
print(search.best_params_)

print("\nBest cross-validation score (average precision):")
print(search.best_score_)


best_model2 = search.best_estimator_

print(best_model2)
results_df2 = pd.DataFrame(search.cv_results_)
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits

# %% [markdown]
# ### Building Optimized Model

# %%
model = XGBClassifier(objective="binary:logistic", random_state = 42,
                     subsample=0.6, 
                      scale_pos_weight=2, 
                      n_estimators=85,
                      min_child_weight=1,
                      max_depth=3,
                      learning_rate=0.05,
                      gamma=0.5,
                      colsample_bytree=0.6)

model.fit(X_train, y_train)
test_accuracy = model.score(X_test,y_test)
train_accuracy = model.score(X_train, y_train)

y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:,1]

print(f'Model accuracy:{test_accuracy}')
print(f'training accuracy:{train_accuracy}')
print(f'AUC_ROC_score:{roc_auc_score(y_test, y_prob)}')
# Out:
# Model accuracy:0.8718502519798416
# training accuracy:0.8787037037037037
# AUC_ROC_score:0.931971965907312

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_prob)

print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
print(f"ROC-AUC  : {roc_auc:.4f}")
print(classification_report(y_test,y_pred, target_names=['Retained', 'Churned']))
# Out:
# Accuracy : 0.8719
# Precision: 0.8427
# Recall   : 0.8486
# F1 Score : 0.8456
# ROC-AUC  : 0.9320

# %%
#confusion matrix


plt.figure(figsize=(4,4))
cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm,
                    display_labels=['Retained', 'Churned']).plot()

#ROC Curve
#  ROC points
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Calculate AUC
auc = roc_auc_score(y_test, y_prob)

# Plot ROC curve
plt.figure(figsize=(4, 4))
plt.plot(fpr, tpr, label=f"XGBoost (AUC = {auc:.3f})")
plt.plot([0, 1], [0, 1], linestyle="--", label="Random classifier")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Model Performance**
#
# * Accuracy: 87.19%: The model correctly classified about 87% of customers as retained or churned.
# * Precision: 84.27%: Of the customers predicted to churn, about 84% actually churned.
# * Recall: 84.86%: The model identified about 85% of the actual churned customers.
# * ROC-AUC: 0.932: The model has a strong ability to distinguish between churned and retained customers across different classification thresholds.

# %% [markdown]
# Confusion Matrix: 1,447 retained customers were correctly identified, while 975 churned customers were correctly identified. The model produced 182 false positives and 174 false negatives.
#
# ROC Curve: The AUC of 0.932 indicates strong discrimination, with the curve staying well above the random-classifier line.

# %%
features = pd.DataFrame({
    "feature": X_train.columns,
    "importance": model.feature_importances_
})

features = features.sort_values(
    "importance",
    ascending=False
)

top_features = features.head(15).sort_values("importance")

plt.figure(fisize=(4,4))

plt.barh(
    top_features["feature"],
    top_features["importance"]
)

plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("Top 15 XGBoost Features")

plt.show()

# %% [markdown]
# ## SHAP Analysis

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.52.0-cp312-abi3-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: numpy>=2 in c:\users\ahlaw\anaconda3\lib\site-packages (from shap) (2.3.5)
# Requirement already satisfied: scipy in c:\users\ahlaw\anaconda3\lib\site-packages (from shap) (1.16.3)
# Requirement already satisfied: scikit-learn in c:\users\ahlaw\anaconda3\lib\site-packages (from shap) (1.7.2)
# Requirement already satisfied: pandas in c:\users\ahlaw\anaconda3\lib\site-packages (from shap) (2.3.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\ahlaw\anaconda3\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\users\ahlaw\anaconda3\lib\site-packages (from shap) (25.0)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numba in c:\users\ahlaw\anaconda3\lib\site-packages (from shap) (0.62.1)
# Requirement already satisfied: llvmlite in c:\users\ahlaw\anaconda3\lib\site-packages (from shap) (0.45.1)
# Requirement already satisfied: cloudpickle in c:\users\ahlaw\anaconda3\lib\site-packages (from shap) (3.1.1)
# Requirement already satisfied: colorama in c:\users\ahlaw\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ahlaw\anaconda3\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ahlaw\anaconda3\lib\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ahlaw\anaconda3\lib\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ahlaw\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ahlaw\anaconda3\lib\site-packages (from scikit-learn->shap) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ahlaw\anaconda3\lib\site-packages (from scikit-learn->shap) (3.5.0)
# Downloading shap-0.52.0-cp312-abi3-win_amd64.whl (499 kB)
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Installing collected packages: slicer, shap
#
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    ---------------------------------------- 2/2 [shap]
#
# Successfully installed shap-0.52.0 slicer-0.0.8

# %%
import shap

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer(X_test)
plt.figure(figsize=(4,6))
shap.summary_plot(shap_values,
                  X_test,
                  plot_size=(6, 4),
                  show=False
                 )
plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
ax = plt.gca()
ax.xaxis.label.set_size(10)
plt.show()

# %% [markdown]
# Recency was calculated as the number of days since the customer's last order during the observation period. It was calculated using only information available up to day 90 to avoid temporal leakage.

# %% [markdown]
# ## SHAP Analysis
#
# - **SHAP (SHapley Additive exPlanations)** is used to understand how each feature influences the model's predictions.
#
# - In the SHAP beeswarm plot:
#   - Each dot represents one customer.
#   - **Positive SHAP values** push the prediction toward churn.
#   - **Negative SHAP values** push the prediction away from churn.
#   - Red represents higher feature values, while blue represents lower values.
#   - Features are ranked by their **mean absolute SHAP value**, so features at the top have a greater overall impact on predictions.
#
# - `recency_days` is the most influential feature, indicating that recent customer activity is an important predictor of churn in the simulated dataset.
#
# - Other behavioral features such as order frequency, spending, and order gaps also contribute to churn predictions.
#
# - Since the dataset is synthetic, these relationships reflect the assumptions used during data generation and should not be interpreted as real-world customer behavior.
#
# ### SHAP vs XGBoost Feature Importance
#
# - XGBoost feature importance and SHAP measure feature influence differently.
# - XGBoost importance reflects how features contribute to the **tree-building process**, while SHAP measures their **contribution to model predictions**.
# - Therefore, their importance values and rankings can differ.

# %%
|
